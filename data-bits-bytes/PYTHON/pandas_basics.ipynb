# %%
#import pandas with alias pd
import pandas as pd

# %%
#read csv file
top_50 = pd.read_csv('./datasets/spotify-streaming-top-50-world.csv')

# %%
# read the first 5 
top_50.head()
# Out:
#          date  position               song                      artist  \
# 0  2023-05-18         1    Ella Baila Sola              Eslabon Armado
# 1  2023-05-18         2          un x100to  Grupo Frontera & Bad Bunny
# 2  2023-05-18         3    La Bebe - Remix      Yng Lvcas & Peso Pluma
# 3  2023-05-18         4  Cupid - Twin Ver.                 FIFTY FIFTY
# 4  2023-05-18         5            Flowers                 Miley Cyrus
#
#    popularity  duration_ms album_type  total_tracks release_date  is_explicit  \
# 0          89       165671      album            16   2023-04-28        False
# 1          99       194563     single             1   2023-04-17        False
# 2          99       234352     single             2   2023-03-17         True
# 3          97       174253     single             3   2023-02-24        False
# 4          91       200600      album            13   2023-03-10        False
#
#                                      album_cover_url
# ...

# %%
#read the last 10 rows
top_50.tail(10)
# Out:
#              date  position                                           song  \
# 16840  2024-04-20        41                                        Starboy
# 16841  2024-04-20        42  I Remember Everything (feat. Kacey Musgraves)
# 16842  2024-04-20        43                                   Another Love
# 16843  2024-04-20        44                             Whatever She Wants
# 16844  2024-04-20        45                                   Slow It Down
# 16845  2024-04-20        46                                Training Season
# 16846  2024-04-20        47                                        Houdini
# 16847  2024-04-20        48                                    PERRO NEGRO
# 16848  2024-04-20        49                                      Evergreen
# 16849  2024-04-20        50                                          QLONA
#
#                               artist  popularity  duration_ms album_type  \
# ...

# %%
# Get the number of rows and columns in this csv
top_50.shape
# Out:
# (16850, 11)

# %%
#Get information on all the columns
top_50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16850 entries, 0 to 16849
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             16850 non-null  object
#  1   position         16850 non-null  int64
#  2   song             16850 non-null  object
#  3   artist           16850 non-null  object
#  4   popularity       16850 non-null  int64
#  5   duration_ms      16850 non-null  int64
#  6   album_type       16850 non-null  object
#  7   total_tracks     16850 non-null  int64
#  8   release_date     16850 non-null  object
#  9   is_explicit      16850 non-null  bool
#  10  album_cover_url  16850 non-null  object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 1.3+ MB

# %%
#Get the mean, std and others from the csv
top_50.describe()
# Out:
#            position    popularity    duration_ms  total_tracks
# count  16850.000000  16850.000000   16850.000000  16850.000000
# mean      25.500000     90.232819  196721.617864     10.714896
# std       14.431298     11.323718   39443.918462      9.018766
# min        1.000000      0.000000   42166.000000      1.000000
# 25%       13.000000     89.000000  172797.000000      1.000000
# 50%       25.500000     93.000000  194857.000000     12.000000
# 75%       38.000000     95.000000  222369.000000     16.000000
# max       50.000000    100.000000  405906.000000    119.000000
