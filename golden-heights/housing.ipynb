# %%
#import libraries
from faker import Faker
import random
from datetime import datetime
import os
from dotenv import load_dotenv
from pymongo import MongoClient
from bson.objectid import ObjectId

#initiate libraries
fake = Faker()
def configure():
    load_dotenv()
uri = os.getenv('password')

#connections
client = MongoClient(f"mongodb+srv://sbb:{os.getenv('password')}@golden-heights-universi.k3mfjir.mongodb.net/")
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

#connect to database
db = client.golheights
departments_coll = db.department
employees = db.employees
students = db.students
courses = db.course
housing = db.housing
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
campuses = [
    "Evergreen Heights Campus",
    "Summit Valley Campus",
    "Lakeside Vista Campus",
    "Golden Grove Campus"
]
#100
dormitory_singles = [
    "Maplewood Residence", "Cedar Crest Hall", "Oakwood Manor", "Pinehurst Towers", "Birchwood Lodge",
    "Willowbrook Dormitory", "Elmwood Commons", "Aspen Heights", "Magnolia House", "Sunflower Suites",
    "Redwood Ridge Residence", "Ivy League Hall", "Rosewood Residence", "Juniper Junction", "Acorn Apartments",
    "Cypress Court", "Laurel Lane Lodge", "Cherry Blossom Hall", "Evergreen Estate", "Sycamore Springs",
    "Alder Arbor Apartments", "Morning Glory Manor", "Sequoia Summit", "Wildflower Walk Residence", "Chestnut Chalet",
    "Columbine Cottage", "Foxglove Fields", "Honeysuckle House", "Lotus Landing",
    "Magnolia Meadows", "Snowdrop Station", "Thistle Terrace", "Water Lily Lodge", "Yarrow Yard", "Oleander Oasis",
    "Holly Haven", "Buttercup Bunkhouse", "Iris Inn", "Fernwood Fellowship", "Fuchsia Fortress", "Nightshade Nook",
    "Snapdragon Primal Sanctuary", "Dandelion Drive Dormitory", "Eucalyptus Estate", "Gooseberry Gardens", "Hawkweed Hall",
    "Indigo Inn", "Kingcup Keep", "Lemon Balm Lodge", "Moonflower Manor",
    "Tulip Terrace", "Bluebell Bunkhouse", "Wisteria Way Hall", "Poplar Pointe Dormitory", "Daffodil Den",
    "Orchid Oasis", "Clover Court", "Violet Villa", "Marigold Mansion", "Lily Pad Lodge", "Azalea Alley Apartments",
    "Petunia Palace", "Zinnia Zone", "Jasmine Junction", "Sunburst Suites", "Snapdragon Sanctuary", "Cosmos Court",
    "Lavender Lane Residence", "Peony Place", "Aster Acres", "Primrose Park Hall", "Pansy Palace", "Dahlia Domain",
    "Hyacinth Haven", "Geranium Grove",
    "Nasturtium Niche", "Oregano Oasis",
    "Peppermint Place", "Quince Quarters", "Rue Retreat", "Sagebrush Suite", "Tansy Tower", "Verbena Villa",
    "Waxflower Way", "Xyris Xanadu", "Yarrow's Higher Yard", "Zucchini Zone", "Nightingale Nest", "Finchfield Residence",
    "Swallowtail Suites", "Hummingbird Haven", "Starling Sanctuary", "Skylark Lodge", "Osprey Oasis", "Falcon's Roost",
    "Raven Ridge Residence", "Bluejay Bunkhouse", "Cardinal Cottage", "Sparrow Springs", "Eagle's Eyrie"]
#100
dormitory_doubles = [
    "Moonlight Mansion", "Silverstone Suites", "Amber Acres", "Crimson Court", "Diamond District Residence",
    "Emerald Enclave", "Goldcrest Hall", "Sapphire Springs", "Platinum Plaza", "Ruby Ridge Residence",
    "Topaz Tower", "Opal Oasis", "Pearl Palace", "Onyx Outpost", "Quartz Quarters",
    "Crystal Cove Residence", "Jade Junction", "Titanium Terrace", "Garnet Gardens", "Aquamarine Apartments",
    "Turquoise Towers", "Coral Cove Hall", "Ivory Isle", "Obsidian Outlook", "Slate Summit",
    "Sunstone Sanctuary", "Peridot Place", "Indigo Island", "Beryl Bunkhouse", "Cobalt Court",
    "Bronze Brook Residence", "Lapis Lazuli Lodge", "Malachite Manor", "Rose Quartz Residence", "Aragonite Apartments",
    "Sunset Shores Residence", "Midnight Meadows", "Whispering Willow Hall", "Crestwood Cottage", "Mystic Manor",
    "Willow Creek Residence", "Starlight Suite", "Tranquil Terrace", "Serenity Springs", "Ethereal Estate",
    "Dreamscape Dormitory", "Harmony Hall", "Peaceful Pines", "Zen Zone", "Blissful Breeze Residence",
    "Radiant Ridge Residence", "Frosty Falls", "Lullaby Lodge", "Aurora Apartments", "Dawn's Delight",
    "Twilight Tower", "Eclipse Estate", "Sunrise Sanctuary", "Moonshadow Mansion", "Stardust Suites",
    "Starlit Sky Residence", "Cosmic Cove", "Galaxy Gardens", "Nebula Nook", "Asteroid Apartments",
    "Solar Springs", "Lunar Lodge", "Orion Oasis", "Milky Way Manor", "Constellation Court",
    "Celestial Chalet", "Supernova Suite", "Comet Commons", "Interstellar Inn", "Planetary Plaza",
    "Space Station Residence", "Starship Suites", "Astro Acres", "Cosmos Court", "Moonbeam Manor",
    "Satellite Springs", "Astronomy Apartments", "Rocket Ridge Residence", "Cosmic Cottage", "Uranus Utopia",
    "Neptune Nest", "Mercury Mansion", "Venus Villa", "Mars Manor", "Jupiter Junction",
    "Saturn Sanctuary", "Pluto Palace", "Galactic Gardens", "Black Hole Hall", "Solar System Suites"
]
#100
dormitory_triples = [
     "Pitt Palace", "Clooney's Chalet", "Lawrence's Lodge", 
    "Beyoncé's Bungalow 1", "Aniston's Abode", "Cruise's Castle 1", "Hemsworth's Haven", "Gomez's Getaway", 
     "Diaz's Dwelling", "Portman's Penthouse", "Gyllenhaal's Getaway", "Kardashian's Kastle", 
    "Swift's Sanctuary", "Downey's Den", "Jolie's Retreat", "West's Villa", "Jay-Z's Mansion", 
    "Hanks' Haven", "Lopez's Loft", "Smith's Stronghold", "Stone's Sanctuary", "Hathaway's Hideout", 
    "Gosling's Getaway", "Depp's Den", "Pitt's Penthouse", "Cumberbatch's Chalet",
    "Affleck's Abode", "Lawrence Lodge", "Kutcher's Cabin", "Stewart's Sanctuary", "Theron's Tower", 
    "Mendes' Manor", "Johnson's Dwelling", "Roberts' Retreat", "Reynolds' Residence", "Evans' Estate", 
     "Gadot's Getaway", "Damon's Den 1", "Wilde's Waterside", "Jackman's Junction", 
    "Kidman's Keep", "Hart's Hideaway 1", "Hiddleston's Haven", "Kravitz's Kingdom", "Gaga's Grotto",
    "Affleck's Apartment", "Johansson's Manor", "Lively's Lair", "Mendes' Mansion", "Watson's Wharf", 
    "Roberts' Residence", "Perry's Palace", "Damon's Den", "Hart's Hideaway", "Stewart's Sanctuary 1", 
    "Evans' Estate 1", "Reynolds' Retreat", "Hiddleston's Haven 1", "Theron's Tower 1", "Beyoncé's Bungalow", 
    "Cruise's Castle", "Affleck's Abode 2", "Diaz's Dwelling 2", "Gyllenhaal's Getaway 2", "Hanks' Haven 2", 
    "Kardashian's Kastle 2", "Lopez's Loft 2", "Pitt Palace 2", "Pitt's Penthouse 2", "Portman's Penthouse 2", 
    "Smith's Stronghold 2", "Stone's Sanctuary 2", "Swift's Sanctuary 2", "West's Villa 2", "Clooney's Chalet 2", 
    "Jay-Z's Mansion 2", "Jolie's Retreat 2", "Cruise's Castle 2", "Affleck's Apartment 2", "Downey's Den 2", 
    "Lawrence's Lodge 2", "Watson's Wharf 2", "Gomez's Getaway 2", "Lawrence's Lodge 3", "Swift's Sanctuary 3", 
    "Lively's Lair 3", "Perry's Palace 2", "Kardashian's Kastle 3", "Aniston's Abode 2", "Gyllenhaal's Getaway 3", 
    "Cruise's Castle 3", "Beyoncé's Bungalow 2", "Pitt's Penthouse 3", "Gomez's Getaway 3", "Diaz's Dwelling 3", 
    "Smith's Stronghold 3", "Cruise's Castle 4", "Hanks' Haven 3", "Smith's Stronghold 4", "Cruise's Castle 5", 
    "Gomez's Getaway 4", "Diaz's Dwelling 4", "Kardashian's Kastle 4", "Gomez's Getaway 5", "Diaz's Dwelling 5"
]
#100
dormitory_quads = [
    "Rivendell Residence",
    "The Shire Hall",
    "Bag End Barracks",
    "Lothlórien Lodge",
    "Isengard Inn",
    "Minas Tirith Tower",
    "Gondor Gatehouse",
    "Moria Mansion",
    "Rohan Retreat",
    "Helms Deep Hall",
    "Fangorn Forest Lodge",
    "Edoras Estate",
    "The Prancing Pony Pavilion",
    "Bree Bunkhouse",
    "Mount Doom Dormitory",
    "The Black Gate Barracks",
    "Barad-dûr Dormitory",
    "The Mines of Moria Manor",
    "The Lonely Mountain Lodge",
    "The Mirkwood Mansion",
    "The Grey Havens Hall",
    "The Tower of Orthanc",
    "The Paths of the Dead Palace",
    "The Palantír Penthouse",
    "The Dead Marshes Manor",
    "The Barrow-downs Barracks",
    "The Glittering Caves Condo",
    "The Hill of Erech Hall",
    "The White Tree Tower",
    "The Beacon of Amon Dîn",
    "The Argonath Apartments",
    "The Entwash Estates",
    "The Elvenking's Halls",
    "The Gates of Moria Guesthouse",
    "The Great River Residence",
    "The Mithril Mines Mansion",
    "The House of Tom Bombadil",
    "The Stone of Erech Suites",
    "The Prancing Pony Penthouse",
    "The Stone of Orthanc Suites",
    "The Houses of Healing Haven",
    "The Westfold Wing",
    "The Gladden Fields Residence",
    "The Green Dragon Den",
    "The Black Land Bunkhouse",
    "The Brandywine Bunkhouse",
    "The Tower Hills Tower",
    "The Brown Lands Bunkhouse",
    "The Grey Havens Guesthouse",
    "The Dead Marshes Manor 2",
    "The Stone of Erech Suites 2",
    "The Forest of Lothlórien Lodge",
    "The House of Elrond",
    "The Glittering Caves Condo 2",
    "The Argonath Apartments 2",
    "The Barrow-downs Barracks 2",
    "The Tower of Orthanc 2",
    "The Great River Residence 2",
    "The Palantír Penthouse 2",
    "The Paths of the Dead Palace 2",
    "The Elvenking's Halls 2",
    "The Beacon of Amon Dîn 2",
    "The Mines of Moria Manor 2",
    "The Dead Marshes Manor 3",
    "The Prancing Pony Pavilion 2",
    "The Entwash Estates 2",
    "The White Tree Tower 2",
    "The Gladden Fields Residence 2",
    "The Stone of Orthanc Suites 2",
    "The Black Gate Barracks 2",
    "The House of Tom Bombadil 2",
    "The Grey Havens Guesthouse 2",
    "The Tower Hills Tower 2",
    "The Hill of Erech Hall 2",
    "The Mithril Mines Mansion 2",
    "The Mirkwood Mansion 2",
    "The Rohan Retreat 2",
    "The Shire Hall 2",
    "The Tower of Orthanc 3",
    "The Lonely Mountain Lodge 2",
    "The Tower Hills Tower 3",
    "The Brown Lands Bunkhouse 2",
    "The Hill of Erech Hall 3",
    "The Grey Havens Hall 2",
    "The Grey Havens Guesthouse 3",
    "The Barrow-downs Barracks 3",
    "The Mines of Moria Manor 3",
    "The Gladden Fields Residence 3",
    "The Dead Marshes Manor 4",
    "The White Tree Tower 3",
    "The Glittering Caves Condo 3",
    "The Stone of Orthanc Suites 3",
    "The Palantír Penthouse 3",
    "The House of Tom Bombadil 3",
    "The Beacon of Amon Dîn 3",
    "The Stone of Erech Suites 3",
    "The Entwash Estates 3",
    "The Black Gate Barracks 3",
    "The Great River Residence 3",
    "The Argonath Apartments 3",
    "The Paths of the Dead Palace 3",
    "The Prancing Pony Pavilion 3",
    "The Elvenking's Halls 3",
    "The Mithril Mines Mansion 3",
    "The Rohan Retreat 3",
    "The Mirkwood Mansion 3",
    "The Shire Hall 3",
    "The Tower of Orthanc 4",
    "The Lonely Mountain Lodge 3",
    "The Tower Hills Tower 4",
    "The Hill of Erech Hall 4",
    "The Grey Havens Hall 3",
    "The Grey Havens Guesthouse 4",
    "The Barrow-downs Barracks 4",
    "The Mines of Moria Manor 4",
    "The Gladden Fields Residence 4",
    "The Dead Marshes Manor 5",
    "The White Tree Tower 4",
    "The Glittering Caves Condo 4",
    "The Stone of Orthanc Suites 4",
    "The Palantír Penthouse 4",
    "The House of Tom Bombadil 4",
    "The Beacon of Amon Dîn 4",
    "The Stone of Erech Suites 4",
    "The Entwash Estates 4",
    "The Black Gate Barracks 4",
    "The Great River Residence 4",
    "The Argonath Apartments 4",
    "The Paths of the Dead Palace 4",
    "The Prancing Pony Pavilion 4",
    "The Elvenking's Halls 4",
    "The Mithril Mines Mansion 4",
    "The Rohan Retreat 4",
    "The Mirkwood Mansion 4"
]
#80
studio_doubles = [
    "Winterfell Watchtower", "Casterly Rock Keep", "Dragonstone Den", "Storm's End Stronghold", "Pyke Portcullis",
    "Sunspear Sanctuary", "Highgarden Haven", "Eyrie Eyrie", "Riverrun Retreat Place", "Dreadfort Dungeon",
    "Ironrath Ironhouse", "Harrenhal Hall", "The Wall Watchtower", "Golden Tooth Tower", "Red Keep Residence",
    "Dragonpit Dungeon", "Greywater Garrison", "Sunset Sea Stronghold", "Starfall Sanctuary", "Castle Black Keep",
    "Karhold Keep", "Yronwood Yard", "Horn Hill Hall", "Oldtown Outpost", "Deepwood Den",
    "Winterfell Tower", "Casterly Keep", "Dragonstone Castle", "Storm's End Estate", "Pyke Manor",
    "Sunspear Villa", "Highgarden Mansion", "Eyrie Lodge", "Riverrun House", "Dreadfort Chambers",
    "Ironrath Residence", "Harrenhal Manor", "The Wall Apartment", "Golden Tooth Retreat", "Red Keep Tower",
    "Dragonpit House", "Greywater Cottage", "Sunset Sea Lodge", "Starfall Mansion", "Castle Black Barracks",
    "Karhold Residence", "Yronwood Mansion", "Horn Hill Cottage", "Oldtown Apartment", "Deepwood Cabin",
    "Winterfell Retreat", "Casterly Hall", "Dragonstone Tower", "Storm's End Chalet", "Pyke Residence",
    "Sunspear Residence", "Highgarden Tower", "Eyrie Chalet", "Riverrun Retreat", "Dreadfort Tower",
    "Ironrath House", "Harrenhal Castle", "The Wall Tower", "Golden Tooth Chalet", "Red Keep House",
    "Dragonpit Mansion", "Greywater Tower", "Sunset Sea Chalet", "Starfall Residence", "Castle Black Lodge",
    "Karhold Cabin", "Yronwood Retreat", "Horn Hill Tower", "Oldtown House", "Deepwood Chalet",
    "Winterfell Manor", "Casterly Residence", "Dragonstone Lodge", "Storm's End Tower", "Pyke Chalet"
]
#150
studio_singles = [
    "Central Perk Chambers", "Monica's Apartment", "Chandler's Chalet", "Joey's Loft", "Rachel's Residence",
    "Ross's Retreat", "Phoebe's Penthouse", "Gunther's Getaway", "Janice's Junction", "Ugly Naked Guy's Unit",
    "Smelly Cat Suite", "Coffeehouse Condo", "Ross and Rachel's Roost", "Joey and Chandler's Joint", "Monica and Chandler's Manor",
    "Phoebe's Funky Flat", "Central Perk Chambers 2", "Monica's Apartment 2", "Chandler's Chalet 2", "Joey's Loft 2",
    "Rachel's Residence 2", "Ross's Retreat 2", "Phoebe's Penthouse 2", "Gunther's Getaway 2", "Janice's Junction 2",
    "Ugly Naked Guy's Unit 2", "Smelly Cat Suite 2", "Coffeehouse Condo 2", "Ross and Rachel's Roost 2",
    "Joey and Chandler's Joint 2", "Monica and Chandler's Manor 2", "Phoebe's Funky Flat 2", "Central Perk Chambers 3",
    "Monica's Apartment 3", "Chandler's Chalet 3", "Joey's Loft 3", "Rachel's Residence 3", "Ross's Retreat 3",
    "Phoebe's Penthouse 3", "Gunther's Getaway 3", "Janice's Junction 3", "Ugly Naked Guy's Unit 3", "Smelly Cat Suite 3",
    "Coffeehouse Condo 3", "Ross and Rachel's Roost 3", "Joey and Chandler's Joint 3", "Monica and Chandler's Manor 3",
    "Phoebe's Funky Flat 3", "Central Perk Chambers 4", "Monica's Apartment 4", "Chandler's Chalet 4", "Joey's Loft 4",
    "Rachel's Residence 4", "Ross's Retreat 4", "Phoebe's Penthouse 4", "Gunther's Getaway 4", "Janice's Junction 4",
    "Ugly Naked Guy's Unit 4", "Smelly Cat Suite 4", "Coffeehouse Condo 4", "Ross and Rachel's Roost 4", "Joey and Chandler's Joint 4",
    "Monica and Chandler's Manor 4", "Phoebe's Funky Flat 4", "Central Perk Chambers 5", "Monica's Apartment 5",
    "Chandler's Chalet 5", "Joey's Loft 5", "Rachel's Residence 5", "Ross's Retreat 5", "Phoebe's Penthouse 5",
    "Gunther's Getaway 5", "Janice's Junction 5", "Ugly Naked Guy's Unit 5", "Smelly Cat Suite 5", "Coffeehouse Condo 5",
    "Ross and Rachel's Roost 5", "Joey and Chandler's Joint 5", "Monica and Chandler's Manor 5", "Phoebe's Funky Flat 5",
    "Central Perk Chambers 6", "Monica's Apartment 6", "Chandler's Chalet 6", "Joey's Loft 6", "Rachel's Residence 6",
    "Ross's Retreat 6", "Phoebe's Penthouse 6", "Gunther's Getaway 6", "Janice's Junction 6", "Ugly Naked Guy's Unit 6",
    "Smelly Cat Suite 6", "Coffeehouse Condo 6", "Ross and Rachel's Roost 6", "Joey and Chandler's Joint 6", "Monica and Chandler's Manor 6",
    "Phoebe's Funky Flat 6", "Central Perk Chambers 7", "Monica's Apartment 7", "Chandler's Chalet 7", "Joey's Loft 7",
    "Rachel's Residence 7", "Ross's Retreat 7", "Phoebe's Penthouse 7", "Gunther's Getaway 7", "Janice's Junction 7",
    "Ugly Naked Guy's Unit 7", "Smelly Cat Suite 7", "Coffeehouse Condo 7", "Ross and Rachel's Roost 7", "Joey and Chandler's Joint 7",
    "Monica and Chandler's Manor 7", "Phoebe's Funky Flat 7", "Central Perk Chambers 8", "Monica's Apartment 8",
    "Chandler's Chalet 8", "Joey's Loft 8", "Rachel's Residence 8", "Ross's Retreat 8", "Phoebe's Penthouse 8",
    "Gunther's Getaway 8", "Janice's Junction 8", "Ugly Naked Guy's Unit 8", "Smelly Cat Suite 8", "Coffeehouse Condo 8",
    "Ross and Rachel's Roost 8", "Joey and Chandler's Joint 8", "Monica and Chandler's Manor 8", "Phoebe's Funky Flat 8",
    "Central Perk Chambers 9", "Monica's Apartment 9", "Chandler's Chalet 9", "Joey's Loft 9", "Rachel's Residence 9",
    "Ross's Retreat 9", "Phoebe's Penthouse 9", "Gunther's Getaway 9", "Janice's Junction 9", "Ugly Naked Guy's Unit 9",
    "Smelly Cat Suite 9", "Coffeehouse Condo 9", "Ross and Rachel's Roost 9", "Joey and Chandler's Joint 9", "Monica and Chandler's Manor 9",
    "Phoebe's Funky Flat 9", "Central Perk Chambers 10", "Monica's Apartment 10", "Chandler's Chalet 10", "Joey's Loft 10",
    "Rachel's Residence 10", "Ross's Retreat 10", "Phoebe's Penthouse 10", "Gunther's Getaway 10", "Janice's Junction 10",
    "Ugly Naked Guy's Unit 10", "Smelly Cat Suite 10", "Coffeehouse Condo 10", "Ross and Rachel's Roost 10",
    "Joey and Chandler's Joint 10", "Monica and Chandler's Manor 10", "Phoebe's Funky Flat 10", "Central Perk Chambers 11",
    "Monica's Apartment 11", "Chandler's Chalet 11", "Joey's Loft 11", "Rachel's Residence 11", "Ross's Retreat 11",
    "Phoebe's Penthouse 11", "Gunther's Getaway 11", "Janice's Junction 11", "Ugly Naked Guy's Unit 11", "Smelly Cat Suite 11",
    "Coffeehouse Condo 11", "Ross and Rachel's Roost 11", "Joey and Chandler's Joint 11", "Monica and Chandler's Manor 11",
    "Phoebe's Funky Flat 11", "Central Perk Chambers 12", "Monica's Apartment 12", "Chandler's Chalet 12", "Joey's Loft 12",
    "Rachel's Residence 12", "Ross's Retreat 12", "Phoebe's Penthouse 12", "Gunther's Getaway 12", "Janice's Junction 12",
    "Ugly Naked Guy's Unit 12", "Smelly Cat Suite 12", "Coffeehouse Condo 12", "Ross and Rachel's Roost 12",
    "Joey and Chandler's Joint 12", "Monica and Chandler's Manor 12", "Phoebe's Funky Flat 12", "Central Perk Chambers 13",
    "Monica's Apartment 13", "Chandler's Chalet 13", "Joey's Loft 13", "Rachel's Residence 13", "Ross's Retreat 13",
    "Phoebe's Penthouse 13", "Gunther's Getaway 13", "Janice's Junction 13", "Ugly Naked Guy's Unit 13", "Smelly Cat Suite 13",
    "Coffeehouse Condo 13", "Ross and Rachel's Roost 13", "Joey and Chandler's Joint 13", "Monica and Chandler's Manor 13",
    "Phoebe's Funky Flat 13", "Central Perk Chambers 14", "Monica's Apartment 14", "Chandler's Chalet 14", "Joey's Loft 14",
    "Rachel's Residence 14", "Ross's Retreat 14", "Phoebe's Penthouse 14", "Gunther's Getaway 14", "Janice's Junction 14",
    "Ugly Naked Guy's Unit 14", "Smelly Cat Suite 14", "Coffeehouse Condo 14", "Ross and Rachel's Roost 14",
    "Joey and Chandler's Joint 14", "Monica and Chandler's Manor 14", "Phoebe's Funky Flat 14", "Central Perk Chambers 15",
    "Monica's Apartment 15", "Chandler's Chalet 15", "Joey's Loft 15", "Rachel's Residence 15", "Ross's Retreat 15",
    "Phoebe's Penthouse 15", "Gunther's Getaway 15", "Janice's Junction 15", "Ugly Naked Guy's Unit 15", "Smelly Cat Suite 15",
    "Coffeehouse Condo 15", "Ross and Rachel's Roost 15", "Joey and Chandler's Joint 15", "Monica and Chandler's Manor 15",
    "Phoebe's Funky Flat 15"
]

# %%
singles = []
doubles = []
for x in studio_singles:
    if x in singles:
        doubles.append(x)
        print(x)
    else:
        singles.append(x)

# %%
#dormitory_singles
evergreen_dormitory_singles = dormitory_singles[:25]; summit_dormitory_singles = dormitory_singles[25:50]; lakeside_dormitory_singles = dormitory_singles[50:75]
golden_grove_dormitory_singles = dormitory_singles[75:]
dorm_singles = [evergreen_dormitory_singles,summit_dormitory_singles,lakeside_dormitory_singles,golden_grove_dormitory_singles]
#dormitory_doubles
evergreen_dormitory_doubles = dormitory_doubles[:25]; summit_dormitory_doubles = dormitory_doubles[25:50]; lakeside_dormitory_doubles = dormitory_doubles[50:75]
golden_grove_dormitory_doubles = dormitory_doubles[75:]
dorm_doubles = [evergreen_dormitory_doubles,summit_dormitory_doubles,lakeside_dormitory_doubles,golden_grove_dormitory_doubles]
#dormitory_triples
evergreen_dormitory_triples = dormitory_triples[:25]; summit_dormitory_triples = dormitory_triples[25:50]; lakeside_dormitory_triples = dormitory_triples[50:75]
golden_grove_dormitory_triples = dormitory_triples[75:]
dorm_triples = [evergreen_dormitory_triples,summit_dormitory_triples,lakeside_dormitory_triples,golden_grove_dormitory_triples]
#dormitory_quads
evergreen_dormitory_quads = dormitory_quads[:25]; summit_dormitory_quads = dormitory_quads[25:50]; lakeside_dormitory_quads = dormitory_quads[50:75]
golden_grove_dormitory_quads = dormitory_quads[75:]
dorm_quads = [evergreen_dormitory_quads,summit_dormitory_quads,lakeside_dormitory_quads,golden_grove_dormitory_quads]
#studio_doubles
evergreen_studio_doubles = studio_doubles[:20]; summit_studio_doubles = studio_doubles[20:40]; lakeside_studio_doubles = studio_doubles[40:60]
golden_grove_studio_doubles = studio_doubles[60:]
stud_doubles = [evergreen_studio_doubles,summit_studio_doubles,lakeside_studio_doubles,golden_grove_studio_doubles]
#studio_singles
evergreen_studio_singles = studio_singles[:37]; summit_studio_singles = studio_singles[37:74]; lakeside_studio_singles = studio_singles[74:111]
golden_grove_studio_singles = studio_singles[111:]
stud_singles = [evergreen_studio_singles,summit_studio_singles,lakeside_studio_singles,golden_grove_studio_singles]

# %%
print(len(lakeside_dormitory_quads))
# Out:
# 25

# %%
print(len(evergreen_studio_doubles))
print(len(summit_studio_doubles))
print(len(lakeside_studio_doubles))
print(len(golden_grove_studio_doubles))
# Out:
# 20
# 20
# 20
# 20

# %%
#Dormitory Availabilities
for campus_dorm in dorm_singles:
    for room in campus_dorm:
        if room in evergreen_dormitory_singles:
            campus = "Evergreen Heights Campus"
        elif room in summit_dormitory_singles:
            campus = "Summit Valley Campus"
        elif room in lakeside_dormitory_singles:
            campus = "Lakeside Vista Campus"
        elif room in golden_grove_dormitory_singles:
            campus = "Golden Grove Campus"
        room_name = room
        capacity = 1
        type = "Dormitory Single"
        rent = random.randint(800,1500)
        status = "Unoccupied"
        students = []
        room_id = str(campus[:3])+str(room[:3])+str(type[4:7])+str(rent)
        housing.insert_one({"room_id":room_id,"room_name":room_name,"capacity":capacity,"campus":campus,"type":type,"rent":rent,"status":status, "students": students})

for campus_dorm in dorm_doubles:
    for room in campus_dorm:
        if room in evergreen_dormitory_doubles:
            campus = "Evergreen Heights Campus"
        elif room in summit_dormitory_doubles:
            campus = "Summit Valley Campus"
        elif room in lakeside_dormitory_doubles:
            campus = "Lakeside Vista Campus"
        elif room in golden_grove_dormitory_doubles:
            campus = "Golden Grove Campus"
        room_name = room
        capacity = 2
        type = "Dormitory Double"
        rent = random.randint(600,1200)
        status = "Unoccupied"
        students = []
        room_id = str(campus[:3])+str(room[:3])+str(type[4:7])+str(rent)
        housing.insert_one({"room_id":room_id,"room_name":room_name,"capacity":capacity,"campus":campus,"type":type,"rent":rent,"status":status, "students": students})
        
for campus_dorm in dorm_triples:
    for room in campus_dorm:
        if room in evergreen_dormitory_triples:
            campus = "Evergreen Heights Campus"
        elif room in summit_dormitory_triples:
            campus = "Summit Valley Campus"
        elif room in lakeside_dormitory_triples:
            campus = "Lakeside Vista Campus"
        elif room in golden_grove_dormitory_triples:
            campus = "Golden Grove Campus"
        room_name = room
        capacity = 3
        type = "Dormitory Triple"
        rent = random.randint(500,1000)
        status = "Unoccupied"
        students = []
        room_id = str(campus[:3])+str(room[:3])+str(type[4:7])+str(rent)
        housing.insert_one({"room_id":room_id,"room_name":room_name,"capacity":capacity,"campus":campus,"type":type,"rent":rent,"status":status, "students": students})

for campus_dorm in dorm_quads:
    for room in campus_dorm:
        if room in evergreen_dormitory_quads:
            campus = "Evergreen Heights Campus"
        elif room in summit_dormitory_quads:
            campus = "Summit Valley Campus"
        elif room in lakeside_dormitory_quads:
            campus = "Lakeside Vista Campus"
        elif room in golden_grove_dormitory_quads:
            campus = "Golden Grove Campus"
        room_name = room
        capacity = 4
        type = "Dormitory Quad"
        rent = random.randint(400,800)
        status = "Unoccupied"
        students = []
        room_id = str(campus[:3])+str(room[:3])+str(type[4:7])+str(rent)
        housing.insert_one({"room_id":room_id,"room_name":room_name,"capacity":capacity,"campus":campus,"type":type,"rent":rent,"status":status, "students": students})

# %%
#Studio Availabilities
for campus_studio in stud_doubles:
    for room in campus_studio:
        if room in evergreen_studio_doubles:
            campus = "Evergreen Heights Campus"
        elif room in summit_studio_doubles:
            campus = "Summit Valley Campus"
        elif room in lakeside_studio_doubles:
            campus = "Lakeside Vista Campus"
        elif room in golden_grove_studio_doubles:
            campus = "Golden Grove Campus"
        room_name = room
        capacity = 2
        type = "Studio Double"
        rent = random.randint(1200,1600)
        status = "Unoccupied"
        students = []
        room_id = str(campus[:3])+str(room[:3])+str(type[4:7])+str(rent)
        housing.insert_one({"room_id":room_id,"room_name":room_name,"capacity":capacity,"campus":campus,"type":type,"rent":rent,"status":status, "students": students})

for campus_studio in stud_singles:
    for room in campus_studio:
        if room in evergreen_studio_singles:
            campus = "Evergreen Heights Campus"
        elif room in summit_studio_singles:
            campus = "Summit Valley Campus"
        elif room in lakeside_studio_singles:
            campus = "Lakeside Vista Campus"
        elif room in golden_grove_studio_singles:
            campus = "Golden Grove Campus"
        room_name = room
        capacity = 1
        type = "Studio Single"
        rent = random.randint(2100,2500)
        status = "Unoccupied"
        students = []
        room_id = str(campus[:3])+str(room[:3])+str(type[4:7])+str(rent)
        housing.insert_one({"room_id":room_id,"room_name":room_name,"capacity":capacity,"campus":campus,"type":type,"rent":rent,"status":status, "students": students})

# %%
housing_availabilities = ["Studio Single","Studio Double","Dormitory Single","Dormitory Double","Dormitory Triple","Dormitory Quad"]

# %%
housing = db.housing
students = db.students
all_students = students.find({})
for student in all_students:
    type = random.choice(housing_availabilities)
    print(type, student["campus"])
    try:
        chosen_housing = housing.find_one({"campus":student["campus"],"type":type, "capacity": {"$gt": 0}})
        # print(chosen_housing["capacity"])
        if chosen_housing["capacity"] > 3:
            housing.update_one({"_id":ObjectId(chosen_housing["_id"])},{"$push":{"students":student["student_id"]},"$set":{"capacity": 3,"status": "Partially Occupied"}}),
            students.update_one({"_id":ObjectId(student["_id"])},{"$set":{"housing":chosen_housing["room_id"]}})
            continue
        elif chosen_housing["capacity"] > 2:
            housing.update_one({"_id":ObjectId(chosen_housing["_id"])},{"$push":{"students":student["student_id"]},"$set":{"capacity": 2,"status": "Partially Occupied"}}),
            students.update_one({"_id":ObjectId(student["_id"])},{"$set":{"housing":chosen_housing["room_id"]}})
            continue
        elif chosen_housing["capacity"] > 1:
            housing.update_one({"_id":ObjectId(chosen_housing["_id"])},{"$push":{"students":student["student_id"]},"$set":{"capacity": 1,"status": "Partially Occupied"}}),
            students.update_one({"_id":ObjectId(student["_id"])},{"$set":{"housing":chosen_housing["room_id"]}})
            continue
        elif chosen_housing["capacity"] > 0:
            housing.update_one({"_id":ObjectId(chosen_housing["_id"])},{"$push":{"students":student["student_id"]},"$set":{"capacity": 0,"status": "Fully Occupied"}}),
            students.update_one({"_id":ObjectId(student["_id"])},{"$set":{"housing":chosen_housing["room_id"]}})
            continue
    except:
        students.update_one({"_id":ObjectId(student["_id"])},{"$set":{"housing":"Pending"}})
        print("failed")
        continue

# %%
housing = db.housing
students = db.students
all_students = students.find({"housing": "Pending","campus": "Golden Grove Campus"})
for student in all_students:
    type = random.choice(housing_availabilities)
    print(type, student["campus"])
    try:
        type = random.choice(housing_availabilities)
        chosen_housing = housing.find_one({"campus":student["campus"],"type":type, "capacity": {"$gt": 0}})
        # print(chosen_housing["capacity"])
        if chosen_housing["capacity"] > 3:
            housing.update_one({"_id":ObjectId(chosen_housing["_id"])},{"$push":{"students":student["student_id"]},"$set":{"capacity": 3,"status": "Partially Occupied"}}),
            students.update_one({"_id":ObjectId(student["_id"])},{"$set":{"housing":chosen_housing["room_id"]}})
            continue
        elif chosen_housing["capacity"] > 2:
            housing.update_one({"_id":ObjectId(chosen_housing["_id"])},{"$push":{"students":student["student_id"]},"$set":{"capacity": 2,"status": "Partially Occupied"}}),
            students.update_one({"_id":ObjectId(student["_id"])},{"$set":{"housing":chosen_housing["room_id"]}})
            continue
        elif chosen_housing["capacity"] > 1:
            housing.update_one({"_id":ObjectId(chosen_housing["_id"])},{"$push":{"students":student["student_id"]},"$set":{"capacity": 1,"status": "Partially Occupied"}}),
            students.update_one({"_id":ObjectId(student["_id"])},{"$set":{"housing":chosen_housing["room_id"]}})
            continue
        elif chosen_housing["capacity"] > 0:
            housing.update_one({"_id":ObjectId(chosen_housing["_id"])},{"$push":{"students":student["student_id"]},"$set":{"capacity": 0,"status": "Fully Occupied"}}),
            students.update_one({"_id":ObjectId(student["_id"])},{"$set":{"housing":chosen_housing["room_id"]}})
            chosen_housing = housing.find_one({"campus":student["campus"],"type":type, "capacity": 0})
    except:
        students.update_one({"_id":ObjectId(student["_id"])},{"$set":{"housing":"External Housing"}})
        print("failed")
        continue
# Out:
# failed
# Studio Double Golden Grove Campus
# failed
# Dormitory Double Golden Grove Campus
# failed
# Dormitory Double Golden Grove Campus
# failed
# Dormitory Quad Golden Grove Campus
# failed
# Studio Double Golden Grove Campus
# failed
# Dormitory Triple Golden Grove Campus
# failed
# Studio Double Golden Grove Campus
# failed
# Dormitory Quad Golden Grove Campus
# failed
# Studio Single Golden Grove Campus
# failed
# Dormitory Quad Golden Grove Campus
# failed
# Dormitory Double Golden Grove Campus

# %%
housing = db.housing
students = db.students
all_students = students.find({"housing": "External Housing"})
for student in all_students:
    type = random.choice(housing_availabilities)
    print(type, student["campus"])
    try:
        type = random.choice(housing_availabilities)
        chosen_housing = housing.find_one({"campus":student["campus"],"type":type, "capacity": {"$gt": 0}})
        # print(chosen_housing["capacity"])
        if chosen_housing["capacity"] > 3:
            housing.update_one({"_id":ObjectId(chosen_housing["_id"])},{"$push":{"students":student["student_id"]},"$set":{"capacity": 3,"status": "Partially Occupied"}}),
            students.update_one({"_id":ObjectId(student["_id"])},{"$set":{"housing":chosen_housing["room_id"]}})
            continue
        elif chosen_housing["capacity"] > 2:
            housing.update_one({"_id":ObjectId(chosen_housing["_id"])},{"$push":{"students":student["student_id"]},"$set":{"capacity": 2,"status": "Partially Occupied"}}),
            students.update_one({"_id":ObjectId(student["_id"])},{"$set":{"housing":chosen_housing["room_id"]}})
            continue
        elif chosen_housing["capacity"] > 1:
            housing.update_one({"_id":ObjectId(chosen_housing["_id"])},{"$push":{"students":student["student_id"]},"$set":{"capacity": 1,"status": "Partially Occupied"}}),
            students.update_one({"_id":ObjectId(student["_id"])},{"$set":{"housing":chosen_housing["room_id"]}})
            continue
        elif chosen_housing["capacity"] > 0:
            housing.update_one({"_id":ObjectId(chosen_housing["_id"])},{"$push":{"students":student["student_id"]},"$set":{"capacity": 0,"status": "Fully Occupied"}}),
            students.update_one({"_id":ObjectId(student["_id"])},{"$set":{"housing":chosen_housing["room_id"]}})
            chosen_housing = housing.find_one({"campus":student["campus"],"type":type, "capacity": 0})
    except:
        students.update_one({"_id":ObjectId(student["_id"])},{"$set":{"housing":"External Housing"}})
        print("failed")
        continue
