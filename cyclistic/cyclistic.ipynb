# %%
import pandas as pd
import openpyxl

# %%
june = pd.read_excel('202206-divvy-tripdata.xlsx')
july = pd.read_excel('202207-divvy-tripdata.xlsx')
august = pd.read_excel('202208-divvy-tripdata.xlsx')
september = pd.read_excel('202209-divvy-publictripdata.xlsx')
october = pd.read_excel('202210-divvy-tripdata.xlsx')
november = pd.read_excel('202211-divvy-tripdata.xlsx')
december = pd.read_excel('202212-divvy-tripdata.xlsx')
january = pd.read_excel('202301-divvy-tripdata.xlsx')
february = pd.read_excel('202302-divvy-tripdata.xlsx')
march = pd.read_excel('202303-divvy-tripdata.xlsx')
april = pd.read_excel('202304-divvy-tripdata.xlsx')
may = pd.read_excel('202305-divvy-tripdata.xlsx')

# %%
final = pd.concat([june,july,august,september,october,november,december,january,february,march,april,may],axis=0)
final
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       600CFD130D0FD2A4  electric_bike 2022-06-30 17:27:53
# 1       F5E6B5C1682C6464  electric_bike 2022-06-30 18:39:52
# 2       B6EB6D27BAD771D2  electric_bike 2022-06-30 11:49:25
# 3       C9C320375DE1D5C6  electric_bike 2022-06-30 11:15:25
# 4       56C055851023BE98  electric_bike 2022-06-29 23:36:50
# ...                  ...            ...                 ...
# 604822  48BDA26F34445546  electric_bike 2023-05-18 10:26:43
# 604823  573025E5EDE10DE1  electric_bike 2023-05-17 14:32:48
# 604824  D88D48898C6FB63E  electric_bike 2023-05-17 07:59:29
# 604825  4692DCD2F87497F5  electric_bike 2023-05-18 08:34:48
# 604826  6ACB7E383473D019  electric_bike 2023-05-29 21:16:58
#
#                   ended_at                       start_station_name  \
# 0      2022-06-30 17:35:15                                      NaN
# 1      2022-06-30 18:47:28                                      NaN
# ...

# %%
cyclicist_final = final.to_csv('cylicist.csv')
