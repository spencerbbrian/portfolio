# %%
#import libraries
from faker import Faker
import random
from datetime import datetime
import os
from dotenv import load_dotenv
from pymongo import MongoClient
from bson.objectid import ObjectId

#initiate libraries
fake = Faker()
def configure():
    load_dotenv()
uri = os.getenv('password')

# %%
#connections
client = MongoClient(f"mongodb+srv://sbb:{os.getenv('password')}@golden-heights-universi.k3mfjir.mongodb.net/")
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

#connect to database
db = client.golheights
departments_coll = db.department
employees = db.employees
students = db.students
courses = db.course
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
cbas = departments_coll.find({"college":"CBAS"})
for x in cbas:
    print(x['department'])
# Out:
# Biology
# Chemistry
# Physics
# Mathematics
# Computer Science
# Geology
# Environmental Science
# Mechanical Engineering
# Electrical Engineering
# Civil Engineering
# Chemical Engineering
# Aerospace Engineering
# Industrial Engineering
# Materials Science
# Architecture
# Agriculture
# Forestry
# Food Science
# Horticulture
# Animal Science
# Marine Biology
# Oceanography
# Meteorology
# Space Sciences
# Astrophysics
# Genetics
# Biomedical Engineering
# Biochemistry
# Cell Biology
# Immunology
# Neurology
# Microbiology
# Pharmacology
# Pathology
# Radiology
# Surgery
# Anesthesiology
# Pediatrics
# Obstetrics and Gynecology
# Psychiatry
# Dermatology
# Oncology
# Emergency Medicine

# %%
departments = ["Biology",
    "Chemistry",
    "Physics",
    "Mathematics",
    "Computer Science",
    "Psychology",
    "Sociology",
    "History",
    "English",
    "Philosophy",
    "Economics",
    "Political Science",
    "Anthropology",
    "Geology",
    "Environmental Science",
    "Mechanical Engineering",
    "Electrical Engineering",
    "Civil Engineering",
    "Chemical Engineering",
    "Aerospace Engineering",
    "Industrial Engineering",
    "Materials Science",
    "Linguistics",
    "Education",
    "Music",
    "Art History",
    "Theater and Dance",
    "Film Studies",
    "Architecture",
    "Business Administration",
    "Marketing",
    "Finance",
    "Accounting",
    "Human Resource Management",
    "International Relations",
    "Public Health",
    "Nutrition",
    "Social Work",
    "Law",
    "Medicine",
    "Nursing",
    "Pharmacy",
    "Dentistry",
    "Veterinary Medicine",
    "Agriculture",
    "Forestry",
    "Food Science",
    "Horticulture",
    "Animal Science",
    "Marine Biology",
    "Oceanography",
    "Meteorology",
    "Space Sciences",
    "Astrophysics",
    "Genetics",
    "Biomedical Engineering",
    "Biochemistry",
    "Cell Biology",
    "Immunology",
    "Neurology",
    "Microbiology",
    "Pharmacology",
    "Pathology",
    "Radiology",
    "Surgery",
    "Anesthesiology",
    "Pediatrics",
    "Obstetrics and Gynecology",
    "Psychiatry",
    "Dermatology",
    "Oncology",
    "Emergency Medicine"
]


for department in departments:
    department_name = department
    department_head = employees.find_one({"department": department_name,"position":"Head of Department"})
    professors = employees.find({"department":department_name,"position": {"$in": ["Professor", "Associate Professor",
                                                                                   "Assistant Professor", "Lecturer"]}})
    dept_faculty_members = []
    dept_courses = []
    for faculty in professors:
        dept_faculty_members.append(faculty['employee_id'])
    department_courses = courses.find({"department":department_name})
    for dept_course in department_courses:
        dept_courses.append(dept_course['course_code'])

    # departments_coll.insert_one({"department":department_name,"Head of Department": department_head['employee_id'],"faculty":dept_faculty_members,
    #                              "courses":dept_courses})

# %%
# Add the total number of students in that departments
all_departments = departments_coll.find({})
for department in all_departments:
    department_name = department['department']
    dept_students = students.count_documents({"department":department_name})
    # departments_coll.update_one({"_id":ObjectId(department["_id"])},{"$set": {"students": dept_students}})

# %%
# Add salaries 

# all_employees = employees.find({})
# for employee in all_employees:
#     if employee["position"] == "Lecturer":
#         lecturer_salary = random.randint(40000,70000)
#         employees.update_one({"_id": ObjectId(employee["_id"])}, {"$set": {"annual_salary": lecturer_salary}})
#     elif employee["position"] == "Assistant Professor" :
#         assistant_professor_salary = random.randint(60000,100000)
#         employees.update_one({"_id": ObjectId(employee["_id"])}, {"$set": {"annual_salary": assistant_professor_salary}})
#     elif employee["position"] == "Associate Professor" :
#         associate_professor_salary = random.randint(70000,120000)
#         employees.update_one({"_id": ObjectId(employee["_id"])}, {"$set": {"annual_salary": associate_professor_salary}})
#     elif employee["position"] == "Professor":
#         professor_salary = random.randint(80000,180000)
#         employees.update_one({"_id": ObjectId(employee["_id"])}, {"$set": {"annual_salary": professor_salary}})
#     elif employee["position"]  == "Head of Department":
#         head_of_department_salary = random.randint(90000,200000)
#         employees.update_one({"_id": ObjectId(employee["_id"])}, {"$set": {"annual_salary": head_of_department_salary}})

# %%
# # Add credit cost to every department for compulsory courses and elective courses
cbas_comp_course = 1300
cbas_elec_course = 1250
cbe_comp_course = 1400
cbe_elec_course = 1200
chsp_comp_course = 1350
chsp_elec_course = 1250
chss_comp_course = 1500
chss_elec_course = 1400

CBAS = [
        "Biology", "Chemistry", "Physics", "Mathematics",
        "Computer Science", "Geology", "Environmental Science",
        "Mechanical Engineering", "Electrical Engineering",
        "Civil Engineering", "Chemical Engineering",
        "Aerospace Engineering", "Industrial Engineering",
        "Materials Science", "Agriculture", "Forestry",
        "Food Science", "Horticulture", "Animal Science",
        "Marine Biology", "Oceanography", "Meteorology",
        "Space Sciences", "Astrophysics", "Genetics",
        "Biomedical Engineering", "Biochemistry", "Cell Biology",
        "Immunology", "Neurology", "Microbiology",
        "Pharmacology", "Pathology", "Radiology",
        "Surgery", "Anesthesiology", "Pediatrics",
        "Obstetrics and Gynecology", "Psychiatry",
        "Dermatology", "Oncology", "Emergency Medicine", "Architecture"
    ]
#College of humanities and social sciences
CHSS = [
        "Psychology", "Sociology", "History", "English",
        "Philosophy", "Anthropology", "Linguistics",
        "Music", "Art History", "Theater and Dance",
        "Film Studies"
    ]
#College of business and economics
CBE = [
        "Economics", "Business Administration",
        "Marketing", "Finance", "Accounting",
        "Human Resource Management", "International Relations"
    ]

CHSP = [
        "Nutrition", "Public Health", "Social Work",
        "Law", "Medicine", "Nursing", "Pharmacy",
        "Dentistry", "Veterinary Medicine", "Political Science", "Education"
    ]

# %%
# for department in departments_coll.find({}):
#     if department['department'] in CBAS:
#         departments_coll.update_one({"_id":ObjectId(department["_id"])},{"$set": {"college": "CBAS", "course_cost": cbas_comp_course,
#                                                                                    "elective_cost": cbas_elec_course}})
#     elif department['department'] in CHSS:
#         departments_coll.update_one({"_id":ObjectId(department["_id"])},{"$set": {"college": "CHSS", "course_cost": chss_comp_course,
#                                                                                    "elective_cost": chss_elec_course}})
#     elif department['department'] in CBE:
#         departments_coll.update_one({"_id":ObjectId(department["_id"])},{"$set": {"college": "CBE", "course_cost": cbe_comp_course,
#                                                                                    "elective_cost": cbe_elec_course}})
#     elif department['department'] in CHSP:
#         departments_coll.update_one({"_id":ObjectId(department["_id"])},{"$set": {"college": "CHSP", "course_cost": chsp_comp_course,
#                                                                                    "elective_cost": chsp_elec_course}})

# %%
course_descriptions = {
    "Biology": "Study of living organisms, ecosystems, and genetics.",
    "Chemistry": "Exploration of matter, its properties, and reactions.",
    "Physics": "Investigation of the physical universe and its principles.",
    "Mathematics": "Advanced study of numbers, equations, and patterns.",
    "Computer Science": "Development of software, algorithms, and AI systems.",
    "Geology": "Examination of Earth's materials, structures, and history.",
    "Environmental Science": "Focus on environmental challenges and sustainability.",
    "Mechanical Engineering": "Design and analysis of machines and systems.",
    "Electrical Engineering": "Study of electrical systems and technologies.",
    "Civil Engineering": "Designing infrastructure like buildings and bridges.",
    "Chemical Engineering": "Applying chemistry in industrial processes.",
    "Aerospace Engineering": "Design of aircraft, spacecraft, and related systems.",
    "Industrial Engineering": "Optimization of processes and systems.",
    "Materials Science": "Study of material properties and applications.",
    "Agriculture": "Science of farming, soil, and crop management.",
    "Forestry": "Sustainable management of forests and ecosystems.",
    "Food Science": "Study of food production, safety, and technology.",
    "Horticulture": "Cultivation of plants, fruits, and landscapes.",
    "Animal Science": "Study of animal biology, breeding, and care.",
    "Marine Biology": "Exploration of marine life and ecosystems.",
    "Oceanography": "Study of oceans, currents, and marine geology.",
    "Meteorology": "Examination of weather systems and forecasting.",
    "Space Sciences": "Study of outer space phenomena and exploration.",
    "Astrophysics": "Focus on the physics of celestial bodies.",
    "Genetics": "Study of DNA, heredity, and genetic engineering.",
    "Biomedical Engineering": "Development of medical technologies and devices.",
    "Biochemistry": "Analysis of chemical processes in living organisms.",
    "Cell Biology": "Study of cell structure and function.",
    "Immunology": "Exploration of immune systems and diseases.",
    "Neurology": "Study of the brain, nerves, and neurological disorders.",
    "Microbiology": "Investigation of microorganisms and their effects.",
    "Pharmacology": "Study of drugs and their biological impacts.",
    "Pathology": "Study of diseases and their causes.",
    "Radiology": "Use of imaging techniques for diagnosis.",
    "Surgery": "Techniques and science of medical operations.",
    "Anesthesiology": "Study of anesthesia and pain management.",
    "Pediatrics": "Focus on child health and diseases.",
    "Obstetrics and Gynecology": "Study of pregnancy and women's health.",
    "Psychiatry": "Diagnosis and treatment of mental illnesses.",
    "Dermatology": "Study of skin health and diseases.",
    "Oncology": "Study and treatment of cancer.",
    "Emergency Medicine": "Care for urgent and life-threatening conditions.",
    "Architecture": "Design and construction of buildings and structures.",
    "Psychology": "Understanding human behavior and mental processes.",
    "Sociology": "Study of social structures and cultural dynamics.",
    "History": "Examination of historical events and their impact.",
    "English": "Study of literature, language, and writing.",
    "Philosophy": "Exploration of fundamental questions about existence.",
    "Anthropology": "Study of human cultures and societies.",
    "Linguistics": "Analysis of language structures and functions.",
    "Music": "Study of music theory, composition, and performance.",
    "Art History": "Exploration of art and its historical context.",
    "Theater and Dance": "Study of performing arts and stagecraft.",
    "Film Studies": "Analysis of cinema and its cultural significance.",
    "Economics": "Study of market systems and economic theories.",
    "Business Administration": "Management of businesses and organizations.",
    "Marketing": "Strategies for promoting goods and services.",
    "Finance": "Study of money management and investments.",
    "Accounting": "Tracking and reporting financial information.",
    "Human Resource Management": "Managing employee relations and recruitment.",
    "International Relations": "Study of global politics and diplomacy.",
    "Nutrition": "Study of diet, health, and food science.",
    "Public Health": "Strategies for improving population health.",
    "Social Work": "Supporting individuals and communities in need.",
    "Law": "Study of legal systems and practices.",
    "Medicine": "Training in medical diagnosis and treatment.",
    "Nursing": "Study of patient care and healthcare systems.",
    "Pharmacy": "Preparing and dispensing medications.",
    "Dentistry": "Study of oral health and dental care.",
    "Veterinary Medicine": "Care and treatment of animals.",
    "Political Science": "Study of political systems and governance.",
    "Education": "Training for teaching and educational development."
}

for key, value in course_descriptions.items():
    for department in departments_coll.find({}):
        if key in department['department']:
            departments_coll.update_one({"department": key}, {"$set": {"description": value}})
