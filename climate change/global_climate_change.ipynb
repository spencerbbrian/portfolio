# %%
#import pandas
import pandas as pd
#import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load global temps csv
global_temps = pd.read_csv(r"C:\\Users\\brian\\Desktop\\portfolio\\climate_change\\original\\GlobalLandTemperatures\\GlobalTemperatures.csv")
global_temps
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0     1750-01-01                   3.034                              3.574
# 1     1750-02-01                   3.083                              3.702
# 2     1750-03-01                   5.626                              3.076
# 3     1750-04-01                   8.490                              2.451
# 4     1750-05-01                  11.573                              2.072
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
# ...

# %%
#Get overview of dataset NA values
global_temps_null = global_temps.isna().sum()
global_temps_null
# Out:
# dt                                              0
# LandAverageTemperature                         12
# LandAverageTemperatureUncertainty              12
# LandMaxTemperature                           1200
# LandMaxTemperatureUncertainty                1200
# LandMinTemperature                           1200
# LandMinTemperatureUncertainty                1200
# LandAndOceanAverageTemperature               1200
# LandAndOceanAverageTemperatureUncertainty    1200
# dtype: int64

# %%
global_temps.dropna()
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 1200  1850-01-01                   0.749                              1.105
# 1201  1850-02-01                   3.071                              1.275
# 1202  1850-03-01                   4.954                              0.955
# 1203  1850-04-01                   7.217                              0.665
# 1204  1850-05-01                  10.004                              0.617
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
# ...

# %%
#Highest Land Average Temperature
global_temps.sort_values('LandAverageTemperature',ascending=False).head(5)
# Out:
#              dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 138  1761-07-01                  19.021                              2.696
# 91   1757-08-01                  17.910                              4.035
# 90   1757-07-01                  17.610                              4.322
# 89   1757-06-01                  17.115                              4.590
# 137  1761-06-01                  16.821                              3.166
#
#      LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 138                 NaN                            NaN                 NaN
# 91                  NaN                            NaN                 NaN
# 90                  NaN                            NaN                 NaN
# 89                  NaN                            NaN                 NaN
# 137                 NaN                            NaN                 NaN
#
# ...

# %%
#Lowest Land Average Temperature
global_temps.sort_values('LandAverageTemperature',ascending=True).head(5)
# Out:
#              dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 216  1768-01-01                  -2.080                              3.027
# 96   1758-01-01                  -1.503                              7.349
# 396  1783-01-01                  -1.431                              5.293
# 756  1813-01-01                  -1.385                              2.191
# 49   1754-02-01                  -1.249                              7.492
#
#      LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 216                 NaN                            NaN                 NaN
# 96                  NaN                            NaN                 NaN
# 396                 NaN                            NaN                 NaN
# 756                 NaN                            NaN                 NaN
# 49                  NaN                            NaN                 NaN
#
# ...

# %%
#Highest LandMax Temperature
global_temps.sort_values('LandMaxTemperature',ascending=False).head(5)
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 3138  2011-07-01                  15.482                              0.113
# 3030  2002-07-01                  15.354                              0.077
# 3090  2007-07-01                  15.230                              0.115
# 3114  2009-07-01                  15.231                              0.148
# 3150  2012-07-01                  15.076                              0.076
#
#       LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 3138              21.320                          0.131               9.684
# 3030              21.199                          0.075               9.409
# 3090              21.108                          0.116               9.482
# 3114              21.085                          0.100               9.456
# 3150              21.006                          0.079               9.229
#
# ...

# %%
#Lowest LandMin Temperature
global_temps.sort_values('LandMinTemperature',ascending=True).head(5)
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 1284  1857-01-01                   1.821                              0.924
# 1716  1893-01-01                   0.500                              0.488
# 1261  1855-02-01                   2.982                              1.322
# 1500  1875-01-01                   1.533                              0.672
# 1644  1887-01-01                   0.824                              0.568
#
#       LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 1284               6.642                          4.164              -5.407
# 1716               5.900                          0.799              -5.345
# 1261               7.604                          3.083              -4.947
# 1500               6.679                          1.047              -4.717
# 1644               6.864                          0.545              -4.678
#
# ...

# %%
#Highest Land And Ocean Average Temperature
global_temps.sort_values('LandAndOceanAverageTemperature',ascending=False).head(5)
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 3186  2015-07-01                  15.051                              0.086
# 2982  1998-07-01                  15.340                              0.074
# 3175  2014-08-01                  14.875                              0.115
# 3187  2015-08-01                  14.755                              0.072
# 3114  2009-07-01                  15.231                              0.148
#
#       LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 3186              20.904                          0.109               9.326
# 2982              20.972                          0.062               9.715
# 3175              20.790                          0.098               9.047
# 3187              20.699                          0.110               9.005
# 3114              21.085                          0.100               9.456
#
# ...

# %%
#Lowest Land And Ocean Average Temperature
global_temps.sort_values('LandAndOceanAverageTemperature',ascending=True).head(5)
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 1332  1861-01-01                   0.404                              0.846
# 1644  1887-01-01                   0.824                              0.568
# 1344  1862-01-01                   0.685                              1.105
# 1716  1893-01-01                   0.500                              0.488
# 1355  1862-12-01                   1.623                              1.010
#
#       LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 1332               7.743                          2.125              -3.256
# 1644               6.864                          0.545              -4.678
# 1344               7.361                          2.394              -4.110
# 1716               5.900                          0.799              -5.345
# 1355               9.402                          2.597              -1.747
#
# ...

# %%
global_temps[["Year","Month","Day"]] = global_temps['dt'].str.split("-",expand=True)
global_temps
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0     1750-01-01                   3.034                              3.574
# 1     1750-02-01                   3.083                              3.702
# 2     1750-03-01                   5.626                              3.076
# 3     1750-04-01                   8.490                              2.451
# 4     1750-05-01                  11.573                              2.072
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
# ...

# %%
global_max_temps = global_temps.groupby("Year")["LandMaxTemperature"].max()

# %%
#Line plot of max Temperature
sns.relplot(x="Year",y="LandMaxTemperature",data=global_temps,kind="line")
plt.show()
