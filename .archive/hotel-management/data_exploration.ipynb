# %%
import pandas as pd
import numpy as np

# 1. Load your data
df = pd.read_csv('hotel_bookings.csv')  # Your 119k rows
df_hotels = pd.read_csv('hotels.csv')   # Your 20 hotel IDs

# 2. Assign a repeating number (1-10) to each booking row
# We group by 'hotel' so that 'Resort' gets 1-10 and 'City' gets 1-10 independently
df['hotel_num'] = df.groupby('hotel').cumcount() % 10 + 1

# 3. Clean the Hotel IDs in the seed dataframe
# We extract the digits from 'RES01' to get '1' so they match our hotel_num
df_hotels['id_num'] = df_hotels['hotel_id'].str.extract('(\d+)').astype(int)

# 4. Perform the "Composite Join"
# We match on BOTH the text (Resort/City) AND the assigned number (1-10)
df_final = pd.merge(
    df, 
    df_hotels, 
    left_on=['hotel', 'hotel_num'], 
    right_on=['hotel_type', 'id_num'], 
    how='left'
)

# 5. Clean up helper columns
df_final = df_final.drop(columns=['hotel_num', 'id_num', 'hotel_type'])

# Check for nulls now
print(f"Nulls in hotel_id: {df_final['hotel_id'].isnull().sum()}")
print(df_final[['hotel', 'hotel_id', 'hotel_name']].head(15))
# Out:
# Nulls in hotel_id: 0
#            hotel hotel_id              hotel_name
# 0   Resort Hotel    RES01      Azure Sands Resort
# 1   Resort Hotel    RES02       Alpine Peak Lodge
# 2   Resort Hotel    RES03     Emerald Bay Retreat
# 3   Resort Hotel    RES04     Sahara Mirage Oasis
# 4   Resort Hotel    RES05       Cancun Sun Palace
# 5   Resort Hotel    RES06     Sydney Harbour View
# 6   Resort Hotel    RES07        Bali Zen Gardens
# 7   Resort Hotel    RES08       Cape Town Coastal
# 8   Resort Hotel    RES09    Maldives Blue Lagoon
# 9   Resort Hotel    RES10  Santorini White Cliffs
# 10  Resort Hotel    RES01      Azure Sands Resort
# 11  Resort Hotel    RES02       Alpine Peak Lodge
# 12  Resort Hotel    RES03     Emerald Bay Retreat
# 13  Resort Hotel    RES04     Sahara Mirage Oasis
# 14  Resort Hotel    RES05       Cancun Sun Palace

# %%
df_final.to_csv('final_bookings.csv', index=False)

# %%
unique_rooms = df['reservation_status'].unique()
print(unique_rooms)
# Out:
# ['Check-Out' 'Canceled' 'No-Show']

# %%
print('\n'.join(df.columns))
# Out:
# hotel
# is_canceled
# lead_time
# arrival_date_year
# arrival_date_month
# arrival_date_week_number
# arrival_date_day_of_month
# stays_in_weekend_nights
# stays_in_week_nights
# adults
# children
# babies
# meal
# country
# market_segment
# distribution_channel
# is_repeated_guest
# previous_cancellations
# previous_bookings_not_canceled
# reserved_room_type
# assigned_room_type
# booking_changes
# deposit_type
# agent
# company
# days_in_waiting_list
# customer_type
# adr
# required_car_parking_spaces
# total_of_special_requests
# reservation_status
# reservation_status_date

# %%
# Drop only columns that exist in the dataframe
columns_to_drop = ['meal', 'booking_changes', 'agent', 'days_in_waiting_list', 'required_car_parking_spaces','company']
columns_to_drop = [col for col in columns_to_drop if col in df.columns]
df = df.drop(columns_to_drop, axis=1)
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# 1                        0                     0       2  ...
# 2                        0                     1       1  ...
# 3                        0                     1       1  ...
# 4                        0                     2       2  ...
#
#    previous_cancellations  previous_bookings_not_canceled reserved_room_type  \
# 0                       0                               0                  C
# 1                       0                               0                  C
# 2                       0                               0                  A
# 3                       0                               0                  A
# 4                       0                               0                  A
#
#   assigned_room_type deposit_type  customer_type   adr  \
# 0                  C   No Deposit      Transient   0.0
# 1                  C   No Deposit      Transient   0.0
# 2                  C   No Deposit      Transient  75.0
# 3                  A   No Deposit      Transient  75.0
# 4                  A   No Deposit      Transient  98.0
#
#    total_of_special_requests reservation_status reservation_status_date
# 0                          0          Check-Out              2015-07-01
# 1                          0          Check-Out              2015-07-01
# 2                          0          Check-Out              2015-07-02
# 3                          0          Check-Out              2015-07-02
# 4                          1          Check-Out              2015-07-03
#
# [5 rows x 26 columns]

# %%
df['arrival_date'] = pd.to_datetime(df['arrival_date_year'].astype(str) + '-' + df['arrival_date_month'] + '-' + df['arrival_date_day_of_month'].astype(str))
df = df.drop(['arrival_date_year', 'arrival_date_month', 'arrival_date_day_of_month', 'arrival_date_week_number'], axis=1)
df.head()
# Out:
#           hotel  is_canceled  lead_time  stays_in_weekend_nights  \
# 0  Resort Hotel            0        342                        0
# 1  Resort Hotel            0        737                        0
# 2  Resort Hotel            0          7                        0
# 3  Resort Hotel            0         13                        0
# 4  Resort Hotel            0         14                        0
#
#    stays_in_week_nights  adults  children  babies country market_segment  ...  \
# 0                     0       2       0.0       0     PRT         Direct  ...
# 1                     0       2       0.0       0     PRT         Direct  ...
# 2                     1       1       0.0       0     GBR         Direct  ...
# 3                     1       1       0.0       0     GBR      Corporate  ...
# 4                     2       2       0.0       0     GBR      Online TA  ...
#
#   previous_bookings_not_canceled  reserved_room_type  assigned_room_type  \
# 0                              0                   C                   C
# 1                              0                   C                   C
# 2                              0                   A                   C
# 3                              0                   A                   A
# 4                              0                   A                   A
#
#    deposit_type customer_type   adr total_of_special_requests  \
# 0    No Deposit     Transient   0.0                         0
# 1    No Deposit     Transient   0.0                         0
# 2    No Deposit     Transient  75.0                         0
# 3    No Deposit     Transient  75.0                         0
# 4    No Deposit     Transient  98.0                         1
#
#   reservation_status  reservation_status_date  arrival_date
# 0          Check-Out               2015-07-01    2015-07-01
# 1          Check-Out               2015-07-01    2015-07-01
# 2          Check-Out               2015-07-02    2015-07-01
# 3          Check-Out               2015-07-02    2015-07-01
# 4          Check-Out               2015-07-03    2015-07-01
#
# [5 rows x 23 columns]

# %%
# df.describe(include='all')
df['estimated_revenue'].describe()
# Out:
# count    119390.000000
# mean        101.831122
# std          50.535790
# min          -6.380000
# 25%          69.290000
# 50%          94.575000
# 75%         126.000000
# max        5400.000000
# Name: adr, dtype: float64

# %% [markdown]
# Cleaning Tasks with dbt
# 1. Remove all Nulls
# 2. Add,year, month into a new column arrival_date. Change arrival date to normal date no numbers and remove all non date like figures
# 3. Convert 0,1s to booleans
# 4. Properly rename columns
# 5. Flag family booking into a new column
# 6. total nights = stays in weekend + stays in week
# 7.
#
# Things to add to the dataset
# 1. Synthetic hotel IDs to distinguish
# 2. Booking revenue
# 3. Understand which countries and customer types (Transient vs. Contract) are the most loyal and profitable.
# Intermediate Layer (int_customer_segments): * Group by country and customer_type.
# Calculate total_bookings, total_canceled_bookings, and average_lead_time.
# Create a flag for "High Value Customers" (e.g., those with ADR > $150).
# Mart Layer (dim_customers): * A table showing the "Profile" of each customer segment.
# KPIs: Cancellation Rate per Country, Average Revenue per Customer Type.
# 4. Help the hotel reduce lost revenue by identifying when and why people cancel.
# Intermediate Layer (int_cancellations_deep_dive): * Calculate the "Days between Booking and Cancellation."
# Flag "Late Cancellations" (canceled less than 7 days before arrival).
# Join with deposit_type to see if non-refundable deposits actually stop cancellations.
# Mart Layer (fct_cancellation_analysis): * KPIs: Revenue Lost (Total ADR of canceled rooms), Most Common Lead Time for Canceled vs. Non-Canceled rooms.
# 5. Identify which months are "Peak" vs. "Off-Peak" to help with pricing strategies
# Identify which months are "Peak" vs. "Off-Peak" to help with pricing strategies.
# Intermediate Layer (int_seasonal_trends): * Extract month and day_of_week from the arrival date.
# Aggregate metrics by is_weekend vs. is_weekday.
# Calculate "Occupancy" (if you assume a total room capacity).
# Mart Layer (fct_seasonal_performance): * KPIs: Weekend vs. Weekday ADR, Monthly Revenue Growth, Busiest Month per Region.
# 6.
#
# Data Quality
# 1. Daily rate is never negative
# 2. Arrival date and hotel is never null
