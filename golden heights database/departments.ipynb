# %%
#import libraries
from faker import Faker
import random
from datetime import datetime
import os
from dotenv import load_dotenv
from pymongo import MongoClient
from bson.objectid import ObjectId

#initiate libraries
fake = Faker()
def configure():
    load_dotenv()
uri = os.getenv('password')

# %%
#connections
client = MongoClient(f"mongodb+srv://sbb:{os.getenv('password')}@golden-heights-universi.k3mfjir.mongodb.net/")
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

#connect to database
db = client.golheights
departments_coll = db.department
employees = db.employees
faculty_employees = db.employee
students = db.student
courses = db.course
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
departments = ["Biology",
    "Chemistry",
    "Physics",
    "Mathematics",
    "Computer Science",
    "Psychology",
    "Sociology",
    "History",
    "English",
    "Philosophy",
    "Economics",
    "Political Science",
    "Anthropology",
    "Geology",
    "Environmental Science",
    "Mechanical Engineering",
    "Electrical Engineering",
    "Civil Engineering",
    "Chemical Engineering",
    "Aerospace Engineering",
    "Industrial Engineering",
    "Materials Science",
    "Linguistics",
    "Education",
    "Music",
    "Art History",
    "Theater and Dance",
    "Film Studies",
    "Architecture",
    "Business Administration",
    "Marketing",
    "Finance",
    "Accounting",
    "Human Resource Management",
    "International Relations",
    "Public Health",
    "Nutrition",
    "Social Work",
    "Law",
    "Medicine",
    "Nursing",
    "Pharmacy",
    "Dentistry",
    "Veterinary Medicine",
    "Agriculture",
    "Forestry",
    "Food Science",
    "Horticulture",
    "Animal Science",
    "Marine Biology",
    "Oceanography",
    "Meteorology",
    "Space Sciences",
    "Astrophysics",
    "Genetics",
    "Biomedical Engineering",
    "Biochemistry",
    "Cell Biology",
    "Immunology",
    "Neurology",
    "Microbiology",
    "Pharmacology",
    "Pathology",
    "Radiology",
    "Surgery",
    "Anesthesiology",
    "Pediatrics",
    "Obstetrics and Gynecology",
    "Psychiatry",
    "Dermatology",
    "Oncology",
    "Emergency Medicine"
]


for department in departments:
    department_name = department
    department_head = faculty_employees.find_one({"department": department_name,"position":"Head of Department"})
    professors = employees.find({"courses.department":department_name,"position": {"$in": ["Professor", "Associate Professor",
                                                                                   "Assistant Professor", "Lecturer"]}})
    dept_faculty_members = []
    dept_courses = []
    for faculty in professors:
        dept_faculty_members.append(faculty['employee_id'])
    department_courses = courses.find({"department":department_name})
    for dept_course in department_courses:
        dept_courses.append(dept_course['course_code'])
    # ({{"$push": {"faculty": {"$each":dept_faculty_members}}}})
    # ({"$push": {"courses": {"$each": dept_courses}}})

    # departments_coll.insert_one({"department":department_name,"Head of Department": department_head['employee_id'],"faculty":dept_faculty_members,
    #                              "courses":dept_courses})
