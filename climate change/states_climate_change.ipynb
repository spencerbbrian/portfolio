# %%
#import pandas
import pandas as pd
#import matplotlib
import matplotlib.pyplot as plt

# %%
#Read states csv file
state_temps = pd.read_csv(r"C:\\Users\\brian\\Desktop\\portfolio\\climate_change\\original\\GlobalLandTemperatures\\GlobalLandTemperaturesByState.csv")
state_temps
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1855-05-01              25.544                          1.171
# 1       1855-06-01              24.228                          1.103
# 2       1855-07-01              24.371                          1.044
# 3       1855-08-01              25.427                          1.073
# 4       1855-09-01              25.675                          1.014
# ...            ...                 ...                            ...
# 645670  2013-05-01              21.634                          0.578
# 645671  2013-06-01              24.679                          0.596
# 645672  2013-07-01              29.272                          1.340
# 645673  2013-08-01              29.202                          0.869
# 645674  2013-09-01                 NaN                            NaN
#
#            State Country
# 0           Acre  Brazil
# 1           Acre  Brazil
# 2           Acre  Brazil
# ...

# %%
state_temps['AverageTemperature'].describe()
# Out:
# count    620027.000000
# mean          8.993111
# std          13.772150
# min         -45.389000
# 25%          -0.693000
# 50%          11.199000
# 75%          19.899000
# max          36.339000
# Name: AverageTemperature, dtype: float64

# %%
max_states_temp = state_temps['AverageTemperature'].max()
state_temps[state_temps['AverageTemperature'] == max_states_temp]
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  State  \
# 116037  2012-06-01              36.339                          0.385  Delhi
#
#        Country
# 116037   India

# %%
min_states_temp = state_temps['AverageTemperature'].min()
state_temps[state_temps['AverageTemperature'] == min_states_temp]
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  State  \
# 484898  1915-01-01             -45.389                          1.839  Sakha
#
#        Country
# 484898  Russia

# %%
ten_hottest_states = state_temps.sort_values('AverageTemperature',ascending=False)
ten_hottest_states.head(10)
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 116037  2012-06-01              36.339                          0.385
# 115833  1995-06-01              36.291                          0.338
# 465520  2010-05-01              36.205                          0.306
# 115077  1932-06-01              36.005                          0.474
# 114969  1923-06-01              35.988                          0.348
# 115005  1926-06-01              35.906                          0.306
# 115628  1978-05-01              35.859                          0.460
# 115257  1947-06-01              35.779                          0.293
# 114729  1903-06-01              35.749                          0.447
# 465256  1988-05-01              35.746                          0.310
#
#             State Country
# 116037      Delhi   India
# 115833      Delhi   India
# 465520  Rajasthan   India
# 115077      Delhi   India
# 114969      Delhi   India
# 115005      Delhi   India
# ...

# %%
ten_coldest_states = state_temps.sort_values('AverageTemperature',ascending=True)
ten_coldest_states.head(10)
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  State  \
# 484898  1915-01-01             -45.389                          1.839  Sakha
# 122606  1915-01-01             -44.736                          2.321  Evenk
# 485090  1931-01-01             -44.715                          1.147  Sakha
# 123374  1979-01-01             -44.586                          0.384  Evenk
# 484718  1900-01-01             -44.453                          2.584  Sakha
# 484826  1909-01-01             -44.155                          2.487  Sakha
# 483974  1838-01-01             -44.027                          3.874  Sakha
# 123255  1969-02-01             -43.856                          0.730  Evenk
# 122629  1916-12-01             -43.820                          2.004  Evenk
# 484622  1892-01-01             -43.734                          4.435  Sakha
#
#        Country
# 484898  Russia
# 122606  Russia
# 485090  Russia
# 123374  Russia
# 484718  Russia
# 484826  Russia
# ...
